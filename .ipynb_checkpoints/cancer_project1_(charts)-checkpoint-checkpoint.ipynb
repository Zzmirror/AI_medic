# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('..\Documents\dataR2.csv')
df
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1  Classification
# 0     7.99585  417.114               1
# 1     4.06405  468.786               1
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)
df
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     43  26.562500      101   10.555  2.629602   9.8000     6.420295
# 1     68  35.560000      131    8.150  2.633537  17.8700    11.900000
# 2     76  27.200000       94   14.070  3.262364  35.8910     9.346630
# 3     59  22.832879       98    6.862  1.658774  14.9037     4.230105
# 4     25  22.860000       82    4.090  0.827271  20.4500    23.670000
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   54  24.218750       86    3.730  0.791257   8.6874     3.705230
# 112   35  35.250761       90    6.817  1.513374  50.6094     6.966895
# 113   51  18.370000      105    6.030  1.561770   9.6200    12.760000
# 114   75  27.300000       85    5.197  1.089638  10.3900     9.000805
# 115   36  28.576676       86    4.345  0.921719  15.1248     8.600000
#
#      Resistin    MCP.1  Classification
# 0    16.10000  806.724               2
# 1     4.19000  198.400               2
# ...

# %%
plt.plot(df[(df['Classification'] == 1)]['Age'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['Age'], 'r^', label='canser')

plt.legend()
plt.xlabel('index')

plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['Glucose'], 'r^', label='cancer')

plt.legend()
plt.xlabel('index')

plt.ylabel('Glucose')
# Out:
# Text(0, 0.5, 'Glucose')

# %%
plt.plot(df[(df['Classification'] == 1)]['BMI'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['BMI'], 'r^', label='cancer')

plt.legend()
plt.xlabel('index')

plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %%
plt.plot(df[(df['Classification'] == 1)]['HOMA'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['HOMA'], 'r^', label='cancer')

plt.legend()
plt.xlabel('index')

plt.ylabel('HOMA')
# Out:
# Text(0, 0.5, 'HOMA')

# %%
plt.plot(df[(df['Classification'] == 1)]['Leptin'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['Leptin'], 'r^', label='canser')

plt.legend()
plt.xlabel('index')

plt.ylabel('Leptin')
# Out:
# Text(0, 0.5, 'Leptin')

# %%
plt.plot(df[(df['Classification'] == 1)]['Adiponectin'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['Adiponectin'], 'r^', label='canser')

plt.legend()
plt.xlabel('index')

plt.ylabel('Adiponectin')
# Out:
# Text(0, 0.5, 'Adiponectin')

# %%
plt.plot(df[(df['Classification'] == 1)]['Resistin'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['Resistin'], 'r^', label='canser')

plt.legend()
plt.xlabel('index')

plt.ylabel('Resistin')
# Out:
# Text(0, 0.5, 'Resistin')

# %%
plt.plot(df[(df['Classification'] == 1)]['MCP.1'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['MCP.1'], 'r^', label='canser')

plt.legend()
plt.xlabel('index')

plt.ylabel('MCP.1')
# Out:
# Text(0, 0.5, 'MCP.1')

# %%
plt.plot(df[(df['Classification'] == 1)]['Insulin'], 'g^', label='healthy')
plt.plot(df[(df['Classification'] == 2)]['Insulin'], 'r^', label='canser')

plt.legend()
plt.xlabel('index')

plt.ylabel('Insulin')
# Out:
# Text(0, 0.5, 'Insulin')

# %%
plt.plot( df[(df['Classification'] == 1)]['Age'],
        df[(df['Classification'] == 1)]['BMI'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Age'],
        df[(df['Classification'] == 2)]['BMI'], 'r^', label='canser')

plt.legend()
plt.xlabel('Age')
plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'],
        df[(df['Classification'] == 1)]['BMI'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Glucose'],
        df[(df['Classification'] == 2)]['BMI'], 'r^', label='canser')

plt.legend()
plt.xlabel('Glucose')

plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %%
plt.plot(df[(df['Classification'] == 1)]['Resistin'],
        df[(df['Classification'] == 1)]['Adiponectin'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Resistin'],
        df[(df['Classification'] == 2)]['Adiponectin'], 'r^', label='canser')

plt.legend()
plt.xlabel('Resistin')
plt.ylabel('Adiponectin')
# Out:
# Text(0, 0.5, 'Adiponectin')

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'],
        df[(df['Classification'] == 1)]['Adiponectin'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Glucose'],
        df[(df['Classification'] == 2)]['Adiponectin'], 'r^', label='canser')

plt.legend()
plt.xlabel('Glucose')
plt.ylabel('Adiponectin')
# Out:
# Text(0, 0.5, 'Adiponectin')

# %%
plt.plot(df[(df['Classification'] == 1)]['Insulin'],
        df[(df['Classification'] == 1)]['Adiponectin'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Insulin'],
        df[(df['Classification'] == 2)]['Adiponectin'], 'r^', label='canser')

plt.legend()
plt.xlabel('Insulin')
plt.ylabel('Adiponectin')
# Out:
# Text(0, 0.5, 'Adiponectin')

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'],
        df[(df['Classification'] == 1)]['Insulin'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Glucose'],
        df[(df['Classification'] == 2)]['Insulin'], 'r^', label='canser')

plt.legend()
plt.xlabel('Glucose')
plt.ylabel('Insulin')
# Out:
# Text(0, 0.5, 'Insulin')

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'],
        df[(df['Classification'] == 1)]['HOMA'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Glucose'],
        df[(df['Classification'] == 2)]['HOMA'], 'r^', label='canser')

plt.legend()
plt.xlabel('Glucose')
plt.ylabel('HOMA')
# Out:
# Text(0, 0.5, 'HOMA')

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'],
        df[(df['Classification'] == 1)]['Leptin'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Glucose'],
        df[(df['Classification'] == 2)]['Leptin'], 'r^', label='canser')

plt.legend()
plt.xlabel('Glucose')
plt.ylabel('Leptin')
# Out:
# Text(0, 0.5, 'Leptin')

# %% [markdown]
# # conclusion :

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'],
        df[(df['Classification'] == 1)]['Resistin'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Glucose'],
        df[(df['Classification'] == 2)]['Resistin'], 'r^', label='canser')

plt.legend()
plt.xlabel('Glucose')
plt.ylabel('Resistin')
# Out:
# Text(0, 0.5, 'Resistin')

# %%
plt.plot(df[(df['Classification'] == 1)]['Glucose'],
        df[(df['Classification'] == 1)]['MCP.1'], 'g^', label='healthy')

plt.plot(df[(df['Classification'] == 2)]['Glucose'],
        df[(df['Classification'] == 2)]['MCP.1'], 'r^', label='canser')

plt.legend()
plt.xlabel('Glucose')
plt.ylabel('MCP.1')
# Out:
# Text(0, 0.5, 'MCP.1')

# %% [markdown]
# in one feature charts :
# there is no horizontal line that can devide tow catecories except for  **Glucose **
